# %%
from mjo_staralt import mjo_vis
# %matplotlib notebook

# %%
date = '2021-11-03'
ra = 44.439697
dec = -11.251092

# %%
mjo_vis(ra=ra,dec=dec,date=date)
# Out:
# <img src="data:image/png;base64,..." width="999.999985098839">
