# %%
from staralt import mjo_alt
# %matplotlib notebook

# %%
date = '2021-11-03'
ra = 44.439697
dec = -11.251092

# %%
mjo_alt(ra=ra,dec=dec,date=date)
# Out:
# <img src="data:image/png;base64,..." width="999.999985098839">
